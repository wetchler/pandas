# %% [markdown]
# # To discuss before starting
# * In this lesson you will code along. The idea is to get used to typing the common commands, and to feel comfortable tinkering with them.
# * NO RUSH to get through all the content -- I'll upload the rest after class, so you can read anything we don't get to. Also the internet is amazing and lots of great pandas tutorials out there.
# * LOOK AT DATA IN EXCEL FIRST (have a google sheets version ready)
#   * Note: I do this sometimes! For simple datasets and simple questions, it's easier. Also easier to share with non-technical colleagues.
# * Much all of this you could do in excel. Why do it here? (power, speed, and replicability)
# * There's more than one way to do EVERYTHING
# * Pandas (like all the libraries we'll use) is deep. There's a lot it can do, but you don't need to know that much to get started. But get used to Googling and using the documentation to learn how to do new things.
#   * Be prepared to learn one bite at a time.

# %% [markdown]
# # Pandas tutorial using happiness data
#
# The data comes from the wonderful "Our World in Data" website, particularly [this page](https://ourworldindata.org/happiness-and-life-satisfaction). If you click on the "data" tab under the first figure, you'll see a download button. We've put that file in this repo, under `data/happiness.csv`
#
# A representative sample of people in each country were asked the "Cantril Ladder" question:
# > _Please imagine a ladder, with steps numbered from 0 at the bottom to 10 at the top. The top of the ladder represents the best possible life for you, and the bottom of the ladder represents the worst possible life for you. On which step of the ladder would you say you personally feel you stand at this time?_

# %% [markdown]
# # Part I

# %% [markdown]
# ## 0. Best practice: put all of your `import`s in _one cell_ at the _top_
# If you have to add more libraries later, add them here and re-run this cell.

# %%
# import pandas
import pandas as pd
# (If Charles doesn't cover it... SHIFT+ENTER, cell outline color / edit mode)

# %% [markdown]
# ## 1. Reading and displaying data

# %%
# Load data

# pd.read_csv('data/happiness.csv')
# pd. (tab)
# pd.read (tab)

# %% [markdown]
# ### Back to work

# %%
# pd.read_excel('data/happiness.xls')
df = pd.read_csv('data/happiness.csv')

# %%
# oof, a bit much
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2008
# 1     Afghanistan  AFG  2009
# 2     Afghanistan  AFG  2010
# 3     Afghanistan  AFG  2011
# 4     Afghanistan  AFG  2012
# 5     Afghanistan  AFG  2013
# 6     Afghanistan  AFG  2014
# 7     Afghanistan  AFG  2015
# 8     Afghanistan  AFG  2016
# 9     Afghanistan  AFG  2017
# 10    Afghanistan  AFG  2018
# 11        Albania  ALB  2007
# 12        Albania  ALB  2009
# 13        Albania  ALB  2010
# 14        Albania  ALB  2011
# 15        Albania  ALB  2012
# 16        Albania  ALB  2013
# 17        Albania  ALB  2014
# 18        Albania  ALB  2015
# 19        Albania  ALB  2016
# 20        Albania  ALB  2017
# 21        Albania  ALB  2018
# 22        Algeria  DZA  2010
# 23        Algeria  DZA  2011
# 24        Algeria  DZA  2012
# 25        Algeria  DZA  2014
# 26        Algeria  DZA  2016
# 27        Algeria  DZA  2017
# 28        Algeria  DZA  2018
# 29         Angola  AGO  2011
# ...           ...  ...   ...
# ...

# %%
# Take a peek
df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2008
# 1  Afghanistan  AFG  2009
# 2  Afghanistan  AFG  2010
# 3  Afghanistan  AFG  2011
# 4  Afghanistan  AFG  2012
#
#    World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))
# 0                                           3.723590
# 1                                           4.401778
# 2                                           4.758381
# 3                                           3.831719
# 4                                           3.782938

# %% [markdown]
# ### * Best practice: Always print the head of a data frame after you load it
# Both for your sake, and for the sake of anyone reading your notebook (say, on GitHub).

# %%
# Why is this a little annoying? (It's all Afghanistan)
# Look at a random sample of rows
df.sample(5)
# Out:
#            Entity Code  Year  \
# 1455        Syria  SYR  2010
# 937      Malaysia  MYS  2015
# 1209  Philippines  PHL  2010
# 1489     Tanzania  TZA  2012
# 1395  South Sudan  SSD  2014
#
#       World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))
# 1455                                           4.464708
# 937                                            6.322121
# 1209                                           4.941514
# 1489                                           4.006897
# 1395                                           3.831992

# %%
# How many rows and columns total?
df.shape
# Out:
# (1704, 4)

# %%
# A few ways to quickly summarize the data (up to you what's most useful)
df.describe()
# Out:
#               Year  \
# count  1704.000000
# mean   2012.332160
# std       3.688072
# min    2005.000000
# 25%    2009.000000
# 50%    2012.000000
# 75%    2015.000000
# max    2018.000000
#
#        World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))
# count                                        1704.000000
# mean                                            5.437155
# std                                             1.121149
# min                                             2.661718
# 25%                                             4.610970
# 50%                                             5.339557
# 75%                                             6.273522
# max                                             8.018934

# %%
# This may seem trivial for this dataset, but sometimes
# you are studying big dataset with hundreds of columns
# and this can help.

# %% [markdown]
# ### 1.3 Pull out parts of the dataframe
#
# These steps are precursors to doing "real work."
#
# Pandas is naturally _column oriented_ -- meaning it's designed to operate quickly on columns of data (not rows). In data analysis you're generally aggregating and summarizing columns (across all rows), so this makes sense.

# %%
# Grab a column (by label)
df['Year']
df['Year'].head()
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# Name: Year, dtype: int64

# %%
# If [] vs () confuses you, a rule of thumb...
# In python, generally, square brackets denote *looking up information inside the object*
# (While parentheses call functions that might do any number of things)
## Think of square brackets like the outline of a book - you're looking stuff up

# %%
# Grab a row (by label)
df.loc[0]
# Out:
# Entity                                                             Afghanistan
# Code                                                                       AFG
# Year                                                                      2008
# World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))        3.72359
# Name: 0, dtype: object

# %%
# Get a specific cell by row/column labels
df.loc[0, 'Year']
# Out:
# 2008

# %%
# Get a subset of rows and columns
# NOTE: this is a general format for subselecting
# part of a dataframe: df.loc[rows of interest, columns of interest]
df.loc[[2, 4, 6], ['Year', 'Entity']]
# Out:
#    Year       Entity
# 2  2010  Afghanistan
# 4  2012  Afghanistan
# 6  2014  Afghanistan

# %%
# Use ':' to say all rows. Since selecting a column is so
# common, you can just use the df['colname'] shorthand
# like we did above
df.loc[:, 'Year'].head()  # Long form of df['Year']
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# Name: Year, dtype: int64

# %%
# How do we get just the happiness numbers column?
# This is a pain in the butt...
df['World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))'].head()
# Out:
# 0    3.723590
# 1    4.401778
# 2    4.758381
# 3    3.831719
# 4    3.782938
# Name: World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best)), dtype: float64

# %% [markdown]
# ### 1.4 Rename columns more legibly (so you don't hate your life)
#
# This will also show you the general pattern of "cleaning up" your dataframe in pandas.

# %%
# df.rename(columns={'World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))': 'happiness'})
# df.head()

# df = df.rename(columns={'World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))': 'happiness'})
# # OR
# df.rename(columns={'World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))': 'happiness'}, inplace=True)
# # OR
df.columns = ['country', 'code', 'year', 'happiness']

# %% [markdown]
# ### * Best practice
# Always print the head of your dataframe when you change it significantly, to be sure it went right

# %%
df.head()
# Out:
#        country code  year  happiness
# 0  Afghanistan  AFG  2008   3.723590
# 1  Afghanistan  AFG  2009   4.401778
# 2  Afghanistan  AFG  2010   4.758381
# 3  Afghanistan  AFG  2011   3.831719
# 4  Afghanistan  AFG  2012   3.782938

# %% [markdown]
# ### * Best practice:
# A common step is to clean your data in one notebook, and save a new, "cleaned" version for future use in other analysis notebooks. Here's how you save your dataframe to a file.

# %%
# "index=False" just means "don't save the row labels" (0, 1, 2, etc)
df.to_csv('data/happiness_cleaned.csv', index=False)

# %% [markdown]
# ## 2. Filter data
# What if we just want to look at one country?

# %%
# df.loc[?]
df[df['country'] == 'United States']
# Note the above is shorthand for df.loc[df['country'] == 'United States', :]
df['country'] == 'United States'
usa = df[df['country'] == 'United States']
usa
# Out:
#             country code  year  happiness
# 1604  United States  USA  2006   7.181794
# 1605  United States  USA  2007   7.512688
# 1606  United States  USA  2008   7.280386
# 1607  United States  USA  2009   7.158032
# 1608  United States  USA  2010   7.163616
# 1609  United States  USA  2011   7.115139
# 1610  United States  USA  2012   7.026227
# 1611  United States  USA  2013   7.249285
# 1612  United States  USA  2014   7.151114
# 1613  United States  USA  2015   6.863947
# 1614  United States  USA  2016   6.803600
# 1615  United States  USA  2017   6.991759
# 1616  United States  USA  2018   6.882685

# %%
df[df['country'] == 'Iceland']
# Notice anything? (not all years present)
# Out:
#      country code  year  happiness
# 642  Iceland  ISL  2008   6.888284
# 643  Iceland  ISL  2012   7.590660
# 644  Iceland  ISL  2013   7.501394
# 645  Iceland  ISL  2015   7.498071
# 646  Iceland  ISL  2016   7.510035
# 647  Iceland  ISL  2017   7.476214

# %%
# How to get just the rows for 2018?
# Anything weird here? (row labels) - be sure to not confuse them for row numbers
df[df['year'] == 2018].head()
# Out:
#         country code  year  happiness
# 10  Afghanistan  AFG  2018   2.694303
# 21      Albania  ALB  2018   5.004403
# 28      Algeria  DZA  2018   5.043086
# 45    Argentina  ARG  2018   5.792797
# 58      Armenia  ARM  2018   5.062449

# %%
# What will this return? (You don't have to type this) Look for a second, and tell me.
# This looks complicated, but you'll get the hang of it.
df.loc[(df['year'] == 2018) & (df['happiness'] > 6), ['country', 'happiness']].head()
# Out:
#        country  happiness
# 70   Australia   7.176993
# 81     Austria   7.396002
# 141    Belgium   6.892172
# 204     Brazil   6.190922
# 270     Canada   7.175497

# %% [markdown]
# ----
# # Part II
# ## _SWITCH DRIVERS_
# 1. `commit` this code
# 1. `push` to github
# 1. have your partner `pull` it down on their laptop
# ----

# %% [markdown]
# ## 3. Let's get cooking. Slice, dice, and summarize your data.
#
# ### Driving question: What are the happiest countries?
# How might we do this? (More than one way...)

# %% [markdown]
# ### 3.1 Sorting

# %%
# What are the happiest countries?
df.sort_values('happiness')
# Q: What's wrong with this? (all years, ascending)
# Out:
#                        country code  year  happiness
# 9                  Afghanistan  AFG  2017   2.661718
# 1458                     Syria  SYR  2013   2.687553
# 274   Central African Republic  CAF  2016   2.693061
# 10                 Afghanistan  AFG  2018   2.694303
# 864                    Liberia  LBR  2015   2.701591
# 1510                      Togo  TGO  2008   2.807855
# 1398               South Sudan  SSD  2017   2.816622
# 1512                      Togo  TGO  2014   2.838959
# 1397               South Sudan  SSD  2016   2.888112
# 1493                  Tanzania  TZA  2016   2.902734
# 230                    Burundi  BDI  2014   2.904535
# 1511                      Togo  TGO  2011   2.936221
# 1675                     Yemen  YEM  2015   2.982674
# 1320              Sierra Leone  SLE  2008   2.997251
# 1678                     Yemen  YEM  2018   3.057514
# 1279                    Rwanda  RWA  2017   3.108374
# 6                  Afghanistan  AFG  2014   3.130896
# ...

# %%
df['year'].max()
# Out:
# 2018

# %%
last_year = df[df['year'] == 2018]
last_year.head()
# ASK WHAT IS STRANGE ABOUT THIS (labels - scroll up to first head())
# Out:
#         country code  year  happiness
# 10  Afghanistan  AFG  2018   2.694303
# 21      Albania  ALB  2018   5.004403
# 28      Algeria  DZA  2018   5.043086
# 45    Argentina  ARG  2018   5.792797
# 58      Armenia  ARM  2018   5.062449

# %%
last_year.sort_values('happiness').head()
# Out:
#           country code  year  happiness
# 10    Afghanistan  AFG  2018   2.694303
# 1678        Yemen  YEM  2018   3.057514
# 927        Malawi  MWI  2018   3.334634
# 1495     Tanzania  TZA  2018   3.445023
# 191      Botswana  BWA  2018   3.461366

# %%
last_year.sort_values('happiness', ascending=False, inplace=True)  # SHOW TAB COMPLETION
# Don't forget!
last_year.head()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#           country code  year  happiness
# 502       Finland  FIN  2018   7.858107
# 416       Denmark  DNK  2018   7.648786
# 1452  Switzerland  CHE  2018   7.508587
# 1076  Netherlands  NLD  2018   7.463097
# 1139       Norway  NOR  2018   7.444262

# %%
# Why doesn't this work?
# last_year.loc[0]

# %%
# GOOGLE IT
last_year.iloc[0]
# Out:
# country      Finland
# code             FIN
# year            2018
# happiness    7.85811
# Name: 502, dtype: object

# %%
last_year.iloc[0]['country']
# Out:
# 'Finland'

# %% [markdown]
# ### OK, how do we find the happiest country _from each year_?

# %%
# Important python command: "range"
range(1, 5)  # Hmm what is this thing?
# Out:
# range(1, 5)

# %%
# This is an "iterable" -- a thing you can use in a for loop
# What do you think this will do? What happened?
for i in range(1, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
# Shorthand - implicitly starts at zero unless you say otherwise
for i in range(5):  # Effectively says "do this 5 times"
    print(i, "- hi")
# Out:
# 0 - hi
# 1 - hi
# 2 - hi
# 3 - hi
# 4 - hi

# %%
# OK, we're ready.
for year in range(df['year'].min(), df['year'].max() + 1):
    oneyear = df[df['year'] == year]
    oneyear = oneyear.sort_values('happiness', ascending=False)
    print(year, oneyear.iloc[0]['country'])
# Out:
# 2005 Denmark
# 2006 Finland
# 2007 Denmark
# 2008 Denmark
# 2009 Denmark
# 2010 Denmark
# 2011 Denmark
# 2012 Switzerland
# 2013 Canada
# 2014 Denmark
# 2015 Norway
# 2016 Finland
# 2017 Finland
# 2018 Finland

# %% [markdown]
# ### 3.2 "Group by" -- your new best friend
# Like pivot tables in excel, but on steroids.
#
# READ the groupby documentation page [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html) -- it's gold and walks you through the conceps. Bookmark it. Refer back to it.

# %% [markdown]
# #### Q: How happy was each country _on average_ across all years surveyed?

# %%
# Pop quiz: how big was our dataframe? How do we find out?
df.shape
# Out:
# (1704, 4)

# %%
df.head()
# Out:
#        country code  year  happiness
# 0  Afghanistan  AFG  2008   3.723590
# 1  Afghanistan  AFG  2009   4.401778
# 2  Afghanistan  AFG  2010   4.758381
# 3  Afghanistan  AFG  2011   3.831719
# 4  Afghanistan  AFG  2012   3.782938

# %%
# What does this do? What does the result mean?
df['happiness'].mean()
# Out:
# 5.437155035744718

# %%
# Group the *rows* that share the same value of a *column*
df.groupby('country')

# %%
# Think of each unique country as having its own little data frame inside the groupby object
grouped = df.groupby('country')
grouped['happiness'].mean().head()
# Out:
# country
# Afghanistan    3.705495
# Albania        4.990211
# Algeria        5.481872
# Angola         4.420299
# Argentina      6.358951
# Name: happiness, dtype: float64

# %%
grouped['happiness'].max().head()
# Out:
# country
# Afghanistan    4.758381
# Albania        5.867422
# Algeria        6.354898
# Angola         5.589001
# Argentina      6.775805
# Name: happiness, dtype: float64

# %%
avg_happiness = grouped['happiness'].mean()
avg_happiness.sort_values(ascending=False).head()
# Out:
# country
# Denmark        7.692072
# Finland        7.554010
# Norway         7.549186
# Switzerland    7.534953
# Netherlands    7.466531
# Name: happiness, dtype: float64

# %%
# You can also "chain" all this stuff together. Up to you.
df.groupby('country')['happiness'].mean().sort_values(ascending=False).head()
# Out:
# country
# Denmark        7.692072
# Finland        7.554010
# Norway         7.549186
# Switzerland    7.534953
# Netherlands    7.466531
# Name: happiness, dtype: float64

# %% [markdown]
# ### What's the _distribution_ of country happinesses?
# Sneak peak into plotting

# %%
last_year.head()
# Out:
#           country code  year  happiness
# 502       Finland  FIN  2018   7.858107
# 416       Denmark  DNK  2018   7.648786
# 1452  Switzerland  CHE  2018   7.508587
# 1076  Netherlands  NLD  2018   7.463097
# 1139       Norway  NOR  2018   7.444262

# %%
# What's a good way to visualize distributions of numbers?
last_year['happiness'].hist()
# Whey is there no plot? (It makes a plot, but we haven't told Jupyter where/how to show it)

# %%
# %matplotlib inline
# BEST PRACTICE - move this to the import block and rerun. Keep it clean.

# %%
# Try it again
last_year['happiness'].hist()
# What's wrong with this? (No axes labels, no title, ugly)

# %%
# Let's look at a country over time
usa = df[df['country'] == 'United States']
usa['happiness'].plot()
# Problems? (X axis is woefully mis-labelled)
# Where did these numbers (1604 etc) come from?

# %%
usa.head()
# Out:
#             country code  year  happiness
# 1604  United States  USA  2006   7.181794
# 1605  United States  USA  2007   7.512688
# 1606  United States  USA  2008   7.280386
# 1607  United States  USA  2009   7.158032
# 1608  United States  USA  2010   7.163616

# %%
usa.set_index('year', inplace=True)  # Note inplace=True
usa.head()
# Out:
#             country code  happiness
# year
# 2006  United States  USA   7.181794
# 2007  United States  USA   7.512688
# 2008  United States  USA   7.280386
# 2009  United States  USA   7.158032
# 2010  United States  USA   7.163616

# %%
usa['happiness'].plot(title='Happiness in America over time')

# %% [markdown]
# ## Stay tuned tomorrow for (much) better plots!

# %% [markdown]
# ## 4. (If time) - joining multiple datasets
# For simplicity here, we're just going to use the data from 2018, `last_year`

# %%
# We made this variable earlier
last_year.head()
# Out:
#           country code  year  happiness
# 502       Finland  FIN  2018   7.858107
# 416       Denmark  DNK  2018   7.648786
# 1452  Switzerland  CHE  2018   7.508587
# 1076  Netherlands  NLD  2018   7.463097
# 1139       Norway  NOR  2018   7.444262

# %% [markdown]
# ### What might cause some countries to be happier? Or correlate with country happiness?
# Lots of things: education, political stability, wealth, healthcare, etc

# %%
# GDP data from the world bank
gdp = pd.read_csv('data/gdp.csv')
gdp.head()
# What's tough about this? (it's big, ugly, and covers more years than we need)
# Out:
#   Country Name Country Code                Indicator Name  Indicator Code  \
# 0        Aruba          ABW  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1  Afghanistan          AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2       Angola          AGO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3      Albania          ALB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4      Andorra          AND  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#         1960       1961       1962       1963       1964        1965  ...  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 1  59.773194  59.860874  58.458015  78.706388  82.095231  101.108305  ...
# 2        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 3        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 4        NaN        NaN        NaN        NaN        NaN         NaN  ...
#
#            2010          2011          2012          2013          2014  \
# ...

# %%
# A common step is to clean your data and save a new, "cleaned" version for future use.
# I've done this for us:
gdp = pd.read_csv('data/gdp_cleaned_2018.csv')
gdp.head()
# Out:
#        country  gdp_per_capita
# 0        Aruba             NaN
# 1  Afghanistan      520.896603
# 2       Angola     3432.385736
# 3      Albania     5253.630064
# 4      Andorra    42029.762737

# %%
# FOR LATER - code I used to clean up the dataset:
# gdp = pd.read_csv('data/gdp.csv')
# column_renames = {
#     'Country Name': 'country',
#     '2018': 'gdp_per_capita'
# }
# gdp.rename(columns=column_renames, inplace=True)
# gdp = gdp[column_renames.values()]
# gdp.to_csv('data/gdp_cleaned_2018.csv', index=False)

# %%
merged = pd.merge(last_year, gdp, on='country')
merged.head()
# Out:
#        country code  year  happiness  gdp_per_capita
# 0      Finland  FIN  2018   7.858107    49960.247050
# 1      Denmark  DNK  2018   7.648786    60595.578029
# 2  Switzerland  CHE  2018   7.508587    82838.929445
# 3  Netherlands  NLD  2018   7.463097    52978.436159
# 4       Norway  NOR  2018   7.444262    81807.198039

# %%
# Why do we only have 120 rows in "merged"?
print(last_year.shape)
print(gdp.shape)
print(merged.shape)
# Out:
# (136, 4)
# (264, 2)
# (120, 5)

# %% [markdown]
# ### The plot thickens... (sorry)

# %%
# What's going on here? Somebody interpret this graph for me.
# Does money stop mattering for happiness?
merged.plot(x='gdp_per_capita', y='happiness', kind='scatter')

# %%
gdp.sort_values('gdp_per_capita', ascending=False).head(10)
# Out:
#               country  gdp_per_capita
# 142        Luxembourg   114340.498742
# 144  Macao SAR, China    86355.407652
# 35        Switzerland    82838.929445
# 175            Norway    81807.198039
# 109           Ireland    77449.720494
# 112           Iceland    73191.116315
# 198             Qatar    69026.468803
# 206         Singapore    64581.944018
# 249     United States    62641.014097
# 168     North America    60968.062155

# %%
# Watch this magic
merged.plot(x='gdp_per_capita', y='happiness', kind='scatter', logx=True)

# %%
# I know I'm violating my "import everything at the top"
# rule here, but this is just a quick demonstration.
import numpy as np
merged['log_gdp'] = np.log10(merged['gdp_per_capita'])
merged.corr()
# Out:
#                 year  happiness  gdp_per_capita   log_gdp
# year             NaN        NaN             NaN       NaN
# happiness        NaN   1.000000        0.728641  0.825354
# gdp_per_capita   NaN   0.728641        1.000000  0.825535
# log_gdp          NaN   0.825354        0.825535  1.000000

# %% [markdown]
# # LASTLY
# 1. Save, `commit` and `push` your code
# 1. Have your partner `pull` it to be sure they see everything
